# %% [markdown]
# # 3) Reconstruct target file with source collection frames
#
# Rebuilds the target using frames chosen from the source collection, and reports what was
# actually placed: how much of the target got covered, how far each chosen frame was from the
# target note's pitch, and how many segments had to be cut short.
#
# The selection and rendering logic lives in [mosaic.py](mosaic.py).

# %%
import os
import subprocess

import numpy as np
import pandas as pd
import essentia
import essentia.standard as estd
import matplotlib.pyplot as plt
from IPython.display import display, Audio

import mosaic

# %%
COLLECTION = 'barnyard'
TARGET_NAME = 'over_the_rainbow'

# Seeded so a demo can be regenerated. Change it to hear a different draw.
SEED = 0

# Which features rank the candidate frames. The three sets compared in the paper:
#   ['mean_pitch']
#   ['mean_pitch', 'loudness']
#   ['mean_pitch', 'loudness'] + mosaic.MFCC_FEATURES
# The features are standardised before the distance is computed (see mosaic.standardize),
# without which mfcc_0 alone accounts for over half of it and loudness for none.
SIMILARITY_FEATURES = ['mean_pitch', 'loudness'] + mosaic.MFCC_FEATURES

# Semitones a chosen frame may differ from the target note. 0 keeps the melody in tune;
# raising it trades tuning for a wider choice of source material.
MAX_PITCH_DEVIATION = 0

# Frames within the pitch limit to pick from at random, for variation between runs.
N_CANDIDATES = 10

df = pd.read_csv('dataframe_{0}.csv'.format(COLLECTION), index_col=0)
df_source = pd.read_csv('dataframe_{0}_source.csv'.format(COLLECTION), index_col=0)
df_target = pd.read_csv('dataframe_{0}_target.csv'.format(TARGET_NAME), index_col=0)

# %%
target_sound_filename = df_target.iloc[0]['path']
target_audio = mosaic.load_audio(target_sound_filename)

generated_audio, report = mosaic.reconstruct(
    df_target,
    df_source,
    SIMILARITY_FEATURES,
    len(target_audio),
    seed=SEED,
    n_candidates=N_CANDIDATES,
    max_pitch_deviation=MAX_PITCH_DEVIATION,
)

print('frames placed:            {0}/{1}'.format(report['frames_placed'], len(df_target)))
print('coverage of the target:   {0:.1%}'.format(report['coverage']))
print('mean |pitch deviation|:   {0:.2f} semitones'.format(report['mean_abs_pitch_deviation']))
print('max  |pitch deviation|:   {0:.2f} semitones'.format(report['max_abs_pitch_deviation']))
print('frames cut short:         {0} (source note shorter than the target note)'.format(
    report['truncated_frames']))

display(pd.DataFrame(report['placements']))

# %%
generated_audio_filename = '{0}.reconstructed.wav'.format(target_sound_filename)
estd.MonoWriter(filename=generated_audio_filename, format='wav',
                sampleRate=mosaic.SAMPLE_RATE)(essentia.array(generated_audio.astype(np.float32)))
print('Saved {0}'.format(generated_audio_filename))

# Credit the sounds actually used. Every Freesound CC-BY sound requires attribution, and
# BY-NC sounds cannot be used commercially.
used_ids = {p['freesound_id'] for p in report['placements']}
used = df[df['freesound_id'].isin(used_ids)]
if len(used) != len(used_ids):
    raise ValueError(
        'Collection metadata is missing {0} of the {1} sounds used, so the result cannot be '
        'attributed. Check that dataframe_{2}.csv matches the analysed collection.'.format(
            len(used_ids) - len(used), len(used_ids), COLLECTION))
display(used[['name', 'username', 'license', 'freesound_id']])

# %%
f, axarr = plt.subplots(2, sharex=True, sharey=True, figsize=(15, 6))
axarr[0].plot(np.arange(len(target_audio)) / mosaic.SAMPLE_RATE, target_audio, linewidth=0.5)
axarr[0].set_title('Target audio')
axarr[1].plot(np.arange(len(generated_audio)) / mosaic.SAMPLE_RATE, generated_audio, linewidth=0.5)
axarr[1].set_title('Reconstructed')
axarr[1].set_xlabel('time [s]')
axarr[1].set_ylim(-1, 1)
plt.show()

print('Target audio')
display(Audio(target_audio, rate=mosaic.SAMPLE_RATE))
print('Reconstructed')
display(Audio(generated_audio, rate=mosaic.SAMPLE_RATE))
print('Reconstruction over a quiet copy of the target')
display(Audio(generated_audio * 0.7 + target_audio * 0.15, rate=mosaic.SAMPLE_RATE))

# %%
# Demo mix, mono: the reconstruction over a quiet copy of the target. The earlier version of
# this hard-panned the reconstruction left and the target right, which misrepresents how the
# result sounds on speakers.
mix = (generated_audio * 0.7 + target_audio * 0.15).astype(np.float32)
peak = np.abs(mix).max()
if peak > 1.0:
    mix = mix / peak

# Encoded with ffmpeg rather than Essentia's AudioWriter, which writes an unplayable file
# and then segfaults on macOS/arm64 with essentia 2.1b6.dev1389.
demo_wav = '{0}_{1}_mix.wav'.format(TARGET_NAME, COLLECTION)
demo_mp3 = '../demo/{0}_{1}_mix.mp3'.format(TARGET_NAME, COLLECTION)
estd.MonoWriter(filename=demo_wav, format='wav',
                sampleRate=mosaic.SAMPLE_RATE)(essentia.array(mix))
subprocess.run(['ffmpeg', '-y', '-loglevel', 'error', '-i', demo_wav, '-b:a', '192k', demo_mp3],
               check=True)
os.remove(demo_wav)
print('Saved {0}'.format(demo_mp3))
